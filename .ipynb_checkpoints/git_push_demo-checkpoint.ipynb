# %%
import numpy as np
import seaborn as sns
import pandas as pd

# %%
data = np.random.normal(170,10,1000)

# %%
sns.histplot(data, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
data2 = np.random.uniform(70,15,2000)

# %%
sns.histplot(data2, kde=True)
# Out:
# <Axes: ylabel='Count'>
